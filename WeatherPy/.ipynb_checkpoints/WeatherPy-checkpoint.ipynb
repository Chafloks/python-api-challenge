# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#creates the URL to make request to weather API
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#Empty lists to store information from cities
name_cities = []
lat_cities = []
lng_cities = []
temp_cities = []
humidity_cities = []
cloud_cities = []
wind_cities = []
count = 0
#Loop to request information from each city
for i in cities:
    weather_response = requests.get(query_url + i).json()
    #We do try in case the values requested do not exist
    try:
        name_cities.append(weather_response["name"])
        lat_cities.append(weather_response["coord"]["lat"])
        lng_cities.append(weather_response["coord"]["lon"])
        temp_cities.append(weather_response["main"]["temp"])
        humidity_cities.append(weather_response["main"]["humidity"])
        cloud_cities.append(weather_response["clouds"]["all"])
        wind_cities.append(weather_response["wind"]["speed"])
        print(f'information added: [{weather_response["name"]}]')
    except KeyError:
        print("city not found")
    count += 1
    if count == 499 :
        time.sleep(60)
        count=0
    
print("----------------------------------------\nProcess completed")
# Out:
# information added: [Chute-aux-Outardes]
# information added: [Atuona]
# information added: [Constitución]
# city not found
# information added: [Rikitea]
# information added: [Ushuaia]
# information added: [Dikson]
# information added: [Along]
# information added: [Port Elizabeth]
# information added: [Malanje]
# information added: [Katsuura]
# information added: [Cape Town]
# information added: [Atar]
# information added: [Camacupa]
# information added: [Aksarka]
# information added: [Pevek]
# information added: [Bemidji]
# information added: [New Norfolk]
# information added: [Sémbé]
# information added: [Salinópolis]
# information added: [Carutapera]
# information added: [Tazovsky]
# information added: [Coyhaique]
# city not found
# information added: [Hilo]
# information added: [Bariloche]
# information added: [Mataura]
# information added: [Beringovskiy]
# information added: [Pozo Colorado]
# information added: [Busselton]
# information added: [São Filipe]
# information added: [Bluff]
# information added: [Arraial do Cabo]
# information added: [Gorontalo]
# information added: [Barrow]
# information added: [Matamoros]
# information added: [Punta Arenas]
# information added: [Albany]
# information added: [Yellowknife]
# information added: [Puerto Ayora]
# information added: [Saskylakh]
# information added: [Tzucacab]
# information added: [Port Alfred]
# city not found
# information added: [Coquimbo]
# information added: [Cherskiy]
# information added: [Tasiilaq]
# information added: [Margate]
# information added: [Bambous Virieux]
# information added: [Dondo]
# city not found
# information added: [Kapaa]
# information added: [Ilulissat]
# information added: [Nara]
# information added: [Vaini]
# information added: [Tuktoyaktuk]
# city not found
# information added: [Sitka]
# information added: [Skibbereen]
# information added: [Avarua]
# information added: [Hithadhoo]
# information added: [Hermanus]
# information added: [Nikolskoye]
# information added: [Kirovskiy]
# information added: [Jalu]
# information added: [Ribeira Grande]
# information added: [Khurai]
# information added: [Adrar]
# information added: [Longyearbyen]
# information added: [Orlik]
# information added: [Trabzon Province]
# information added: [Haines Junction]
# information added: [Port Macquarie]
# information added: [Ponta do Sol]
# information added: [Philadelphia]
# information added: [Yerbogachën]
# information added: [Río Gallegos]
# information added: [Bambanglipuro]
# information added: [Surab]
# information added: [Vestmannaeyjar]
# information added: [Kaoma]
# information added: [Vanavara]
# city not found
# information added: [Korla]
# information added: [Thompson]
# information added: [Chui]
# information added: [Skegness]
# city not found
# information added: [Bilma]
# information added: [Tiksi]
# information added: [Camacha]
# information added: [Fortuna]
# information added: [Kargat]
# information added: [Richards Bay]
# information added: [Kavieng]
# information added: [Vao]
# information added: [Chokurdakh]
# information added: [Karasburg]
# information added: [Kushima]
# information added: [Bredasdorp]
# information added: [‘Ewa Beach]
# information added: [Lorengau]
# information added: [Provideniya]
# information added: [Saint-Philippe]
# information added: [Souillac]
# information added: [Codrington]
# information added: [Kerman]
# information added: [Lagoa]
# information added: [Chernyshevskiy]
# information added: [Abhā]
# information added: [Castro]
# information added: [Khatanga]
# information added: [Kruisfontein]
# information added: [Maracaçumé]
# city not found
# information added: [Tiznit Province]
# information added: [Sergeevka]
# city not found
# information added: [Camaquã]
# information added: [Kaabong]
# information added: [Lewistown]
# city not found
# information added: [Chimbote]
# information added: [Wasilla]
# information added: [Lavrentiya]
# information added: [Bathsheba]
# information added: [Kirakira]
# information added: [Laguna]
# information added: [Cabo San Lucas]
# information added: [Lebu]
# information added: [Aden]
# information added: [Caravelas]
# information added: [Alta Floresta]
# information added: [Mar del Plata]
# information added: [Hong Kong]
# information added: [George Town]
# information added: [Launceston]
# information added: [Qaanaaq]
# information added: [Kieta]
# information added: [East London]
# information added: [Hūn]
# information added: [Rosetown]
# information added: [Butaritari]
# information added: [Bud]
# information added: [Torbay]
# information added: [Iquique]
# information added: [Ocoee]
# information added: [Norman Wells]
# information added: [Hobart]
# information added: [San Cristobal]
# information added: [Kumul]
# information added: [Cumana]
# information added: [Baliton]
# information added: [Mount Isa]
# information added: [Asheboro]
# information added: [Presidencia Roque Sáenz Peña]
# information added: [Morant Bay]
# information added: [Coahuayana Viejo]
# information added: [Catemaco]
# city not found
# information added: [Mayo]
# information added: [Shakawe]
# information added: [Manzanillo]
# information added: [Narsaq]
# information added: [Talnakh]
# information added: [Airai]
# information added: [San Patricio]
# information added: [Natal]
# information added: [Olafsvik]
# information added: [Saint-Honoré]
# information added: [Leshukonskoye]
# information added: [Vardø]
# information added: [Khovd]
# information added: [Tuatapere]
# information added: [Ancud]
# information added: [Kungälv]
# information added: [Beni Mazar]
# city not found
# information added: [Wukari]
# information added: [Kawambwa]
# information added: [Mandera]
# information added: [Kampong Thom]
# information added: [Salalah]
# information added: [Broome]
# information added: [Bethel]
# information added: [Kenai]
# information added: [Djibouti]
# information added: [Vila]
# information added: [Saint Paul Harbor]
# information added: [Eureka]
# information added: [Iqaluit]
# information added: [Kokkola]
# information added: [Palakkad]
# information added: [Hambantota]
# information added: [Bengkulu]
# information added: [Davila]
# information added: [Zaranj]
# information added: [Somain]
# information added: [Nova Olinda do Norte]
# information added: [Kinsale]
# information added: [Alghero]
# information added: [Leningradskiy]
# information added: [Calvià]
# information added: [Ust-Maya]
# information added: [Bandarbeyla]
# information added: [Bella Union]
# information added: [Zhigansk]
# information added: [Arona]
# information added: [Kununurra]
# information added: [Lompoc]
# information added: [San Blas]
# information added: [Acapulco de Juárez]
# information added: [Pāndoh]
# information added: [Mahébourg]
# information added: [Ratnagiri]
# information added: [Arlit]
# information added: [Lajas]
# city not found
# information added: [Suffolk]
# information added: [Okhotsk]
# information added: [Yumaguzino]
# city not found
# information added: [Najrān]
# information added: [Esim]
# information added: [Fort Thomas]
# city not found
# information added: [Lufilufi]
# information added: [Jamestown]
# information added: [Mount Gambier]
# city not found
# information added: [Kurumkan]
# information added: [Redmond]
# information added: [Inírida]
# information added: [Upernavik]
# information added: [Labuhan]
# information added: [Artyom]
# information added: [Inyonga]
# information added: [Beloha]
# information added: [Nuevo Progreso]
# city not found
# information added: [Jinchang]
# information added: [Porto-Novo]
# information added: [Sosnovo-Ozerskoye]
# information added: [Merauke]
# information added: [San Quintín]
# information added: [Tsimmerbude]
# information added: [Saint-Joseph]
# information added: [Northam]
# city not found
# information added: [Sinnamary]
# information added: [Almaznyy]
# city not found
# information added: [Half Moon Bay]
# information added: [Carnarvon]
# information added: [Manggar]
# information added: [Maralal]
# information added: [Krasnosel'kup]
# city not found
# information added: [Honiara]
# information added: [Ko Samui]
# information added: [Necochea]
# information added: [Koslan]
# information added: [Zhangjiakou]
# information added: [Sur]
# information added: [Santa Maria]
# information added: [Kyren]
# information added: [Auki]
# information added: [Revda]
# information added: [Erenhot]
# information added: [Hamilton]
# information added: [Meulaboh]
# information added: [Port Lincoln]
# information added: [Acarí]
# information added: [Porto Santo]
# information added: [Dingle]
# information added: [The Valley]
# information added: [Vila Velha]
# information added: [Ostrovnoy]
# information added: [North Platte]
# information added: [Kärdla]
# information added: [Hasaki]
# information added: [Suntar]
# information added: [Nantucket]
# information added: [Toulouse]
# information added: [Dzhebariki-Khaya]
# information added: [Linfen]
# city not found
# information added: [Uyuni]
# information added: [Poum]
# information added: [Marmaris]
# information added: [Saint-Pierre]
# information added: [Usinsk]
# information added: [Zeya]
# information added: [Longhua]
# information added: [Rosário do Sul]
# information added: [Kathmandu]
# information added: [Muros]
# information added: [Deputatsky]
# information added: [Bilibino]
# information added: [Kahului]
# information added: [Sibolga]
# information added: [Santa Rosa]
# information added: [St. George's]
# city not found
# information added: [Barra de Tecoanapa]
# information added: [Allāpalli]
# information added: [Qasigiannguit]
# information added: [Aksu]
# information added: [Venado Tuerto]
# information added: [Nautla]
# information added: [Sembakung]
# information added: [Antalaha]
# information added: [Pionerskiy]
# information added: [Mercedes]
# information added: [Pak Phanang]
# information added: [Mersin Province]
# information added: [Uribia]
# information added: [Evansville]
# information added: [Puerto Ayacucho]
# information added: [Mizdah]
# information added: [Curvelo]
# information added: [Hokitika]
# information added: [Pedregulho]
# information added: [Ayabaca]
# city not found
# city not found
# information added: [Illapel]
# city not found
# information added: [Sibu]
# information added: [Yagodnoye]
# information added: [Lobito]
# information added: [Lüderitz]
# information added: [Clyde River]
# information added: [Montgomery]
# information added: [Nouadhibou]
# information added: [Grindavik]
# information added: [La Ronge]
# information added: [Barcelona]
# information added: [Aykhal]
# information added: [Puerto del Rosario]
# city not found
# information added: [Cidreira]
# information added: [North Bay]
# information added: [Esperance]
# city not found
# information added: [North Bend]
# information added: [Ocampo]
# information added: [Ljungby]
# information added: [Biak]
# information added: [Kaitangata]
# information added: [Taksimo]
# city not found
# city not found
# information added: [Montepuez]
# city not found
# information added: [Adré]
# information added: [Smithers]
# information added: [Vila Franca do Campo]
# city not found
# city not found
# information added: [Rawson]
# information added: [Elk Plain]
# information added: [Ankpa]
# information added: [Gamba]
# information added: [Moshenskoye]
# information added: [Ternate]
# information added: [Malbork]
# information added: [Praia da Vitória]
# information added: [Miandrivazo]
# information added: [Thinadhoo]
# information added: [Meadow Lake]
# information added: [San Francisco]
# information added: [Geraldton]
# information added: [Walvis Bay]
# information added: [Chifeng]
# information added: [Melfi]
# information added: [Kapoeta]
# information added: [Kostino]
# information added: [Cayenne]
# information added: [Kidodi]
# information added: [Agüimes]
# information added: [Kiruna]
# information added: [Sokolo]
# information added: [Alim]
# information added: [Kinablangan]
# information added: [Kuching]
# city not found
# information added: [Tiarei]
# information added: [Nador]
# information added: [Morgan City]
# information added: [Gaza]
# information added: [Mt. Pleasant]
# information added: [Yanaul]
# city not found
# information added: [Bundaberg]
# information added: [Brae]
# information added: [Payo]
# information added: [Kozhva]
# information added: [Sambava]
# information added: [Pierre]
# information added: [Taoudenni]
# information added: [Dapaong]
# information added: [Aripuanã]
# information added: [Sobolevo]
# information added: [Mackay]
# information added: [Polonnaruwa]
# information added: [Kiryat Gat]
# information added: [Leer]
# information added: [Tanout]
# information added: [Portland]
# information added: [Omsukchan]
# information added: [Asmara]
# information added: [Saldanha]
# information added: [Moyo]
# information added: [São João da Barra]
# information added: [Basoko]
# information added: [Petropavlovsk-Kamchatskiy]
# information added: [Bontang]
# information added: [Troitskoye]
# information added: [Fastovetskaya]
# information added: [Ambon City]
# city not found
# information added: [Payakumbuh]
# information added: [Malaṅgawā]
# information added: [Massakory]
# information added: [Touros]
# city not found
# city not found
# information added: [Harper]
# information added: [Panguna]
# information added: [Zharkent]
# information added: [Bintulu]
# information added: [Chodavaram]
# information added: [Tambopata]
# information added: [Raton]
# information added: [Shingū]
# information added: [Ende]
# information added: [Virginia Beach]
# city not found
# information added: [Nanortalik]
# information added: [Brentwood]
# information added: [Ponta Delgada]
# information added: [Bonito]
# information added: [Vavozh]
# information added: [Severo-Kuril'sk]
# information added: [Gushikawa]
# information added: [Kohima]
# information added: [San Felipe]
# information added: [Uíge]
# city not found
# city not found
# information added: [Anadyr]
# information added: [Vitim]
# information added: [Nyurba]
# information added: [Homer]
# information added: [Baie-Comeau]
# information added: [Madimba]
# information added: [Porto Recanati]
# information added: [Zdvinsk]
# information added: [Coolum Beach]
# information added: [Husavik]
# information added: [Bonavista]
# information added: [San Ramon]
# information added: [Puerto Asís]
# information added: [Kichera]
# city not found
# information added: [Makakilo City]
# information added: [Malakal]
# information added: [Newport]
# information added: [Banyo]
# information added: [Calvinia]
# city not found
# information added: [Karasjok]
# information added: [São Félix do Xingu]
# information added: [Inhambane]
# information added: [Umluj]
# information added: [Saint Anthony]
# information added: [Avera]
# information added: [Vinh]
# information added: [Monrovia]
# information added: [Berlevåg]
# information added: [Alofi]
# information added: [Kuril'sk]
# information added: [Yizheng]
# information added: [Aljezur]
# information added: [Sinop Province]
# information added: [Makar'yev]
# information added: [Boa Vista]
# city not found
# information added: [Dongling]
# information added: [Padang]
# city not found
# information added: [Umba]
# information added: [Pringsewu]
# information added: [General Roca]
# city not found
# information added: [The Pas]
# city not found
# information added: [Qaqortoq]
# information added: [Jaru]
# information added: [Palora]
# information added: [Sorong]
# information added: [Mehamn]
# information added: [Samarai]
# information added: [Pagėgiai]
# information added: [Itarema]
# information added: [Ust-Kuyga]
# information added: [Santa Vitória do Palmar]
# information added: [Eresós]
# information added: [City of San Pedro]
# information added: [Belyy Yar]
# information added: [Bom Jesus]
# information added: [Rocha]
# city not found
# information added: [Saquarema]
# information added: [Weligama]
# information added: [Amapá]
# information added: [Mwandiga]
# information added: [Masuda]
# information added: [Cururupu]
# information added: [Sovetskaya]
# information added: [Dunkirk]
# information added: [Port-Gentil]
# information added: [Klaksvík]
# information added: [Kendari]
# city not found
# information added: [Seybaplaya]
# information added: [Araouane]
# information added: [Balkhash]
# information added: [Taganak]
# information added: [Pisco]
# information added: [Boyolangu]
# information added: [Bataiporã]
# information added: [Mwinilunga]
# information added: [Itoman]
# information added: [Grand Gaube]
# information added: [La Cumbre]
# information added: [Moba]
# city not found
# information added: [Balkanabat]
# information added: [Gisborne]
# information added: [Nakusp]
# information added: [Kurkino]
# information added: [Raudeberg]
# information added: [Slave Lake]
# information added: [Shestakovo]
# information added: [Ucluelet]
# information added: [Byron Bay]
# city not found
# information added: [Bereda]
# information added: [Flinders]
# information added: [Trairi]
# information added: [Egvekinot]
# city not found
# information added: [Gravdal]
# information added: [Morgantown]
# information added: [Ceres]
# information added: [Harnai]
# information added: [Port Hardy]
# information added: [Quang Ngai]
# information added: [Luwuk]
# city not found
# information added: [Neustadt an der Waldnaab]
# information added: [Riohacha]
# information added: [Magnor]
# information added: [Santiago del Estero]
# information added: [Te Anau]
# information added: [Atagay]
# city not found
# city not found
# city not found
# information added: [Nome]
# information added: [Alice Springs]
# information added: [Assaré]
# city not found
# information added: [Rolla]
# information added: [Niltepec]
# information added: [Bojnourd]
# information added: [Wuwei]
# information added: [Malchevskaya]
# information added: [Riyadh]
# information added: [Port-Cartier]
# information added: [Shenjiamen]
# information added: [Kutum]
# information added: [Hualmay]
# information added: [Meiktila]
# information added: [Wolsztyn]
# information added: [Auch]
# information added: [Karia]
# information added: [Ballina]
# information added: [Pascagoula]
# information added: [Wajid]
# information added: [Conde]
# information added: [Spas-Demensk]
# information added: [Zabaykal'sk]
# information added: [Banepā]
# information added: [Marana]
# information added: [Vilyuysk]
# information added: [Quatre Cocos]
# information added: [Bosansko Grahovo]
# city not found
# information added: [Hay River]
# information added: [Comodoro Rivadavia]
# information added: [Tortolì]
# information added: [Podosinovets]
# information added: [Cabedelo]
# information added: [Kochubey]
# information added: [Vanderhoof]
# information added: [Havre-St-Pierre]
# information added: [Barão de Melgaço]
# information added: [Maceió]
# ----------------------------------------
# Process completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#We create a Data Frame from the list
city_dict = {'City': name_cities, 'Latitud': lat_cities, 'Longitud': lng_cities, 'Temperature': temp_cities, 'Humidity': humidity_cities, 'Cloudiness': cloud_cities, 'Wind Speed': wind_cities}
city_df = pd.DataFrame(city_dict)
city_df.head(15)
# Out:
#                   City  Latitud  Longitud  Temperature  Humidity  Cloudiness  \
# 0   Chute-aux-Outardes    49.12    -68.40        16.00       100          90
# 1               Atuona    -9.80   -139.03        25.95        73           5
# 2         Constitución   -35.33    -72.42        10.94        80         100
# 3              Rikitea   -23.12   -134.97        22.84        87          98
# 4              Ushuaia   -54.80    -68.30         2.00        59          20
# 5               Dikson    73.51     80.55        11.92        72         100
# 6                Along    28.17     94.77        22.87        90         100
# 7       Port Elizabeth   -33.92     25.57        10.00        93           2
# 8              Malanje    -9.54     16.34        15.12        35           0
# 9             Katsuura    35.13    140.30        24.63        88          75
# 10           Cape Town   -33.93     18.42         8.92       100           0
# 11                Atar    20.52    -13.05        31.55        44         100
# 12            Camacupa   -12.02     17.48        10.59        48           0
# 13             Aksarka    66.56     67.80         9.10        90           0
# 14               Pevek    69.70    170.31         2.58        96         100
#
#     Wind Speed
# 0         1.00
# 1         7.86
# 2         1.08
# 3         5.84
# 4         1.50
# 5         5.19
# 6         0.22
# 7         2.10
# 8         0.86
# 9         3.10
# 10        1.00
# 11        1.01
# 12        2.03
# 13        2.31
# 14        4.13

# %%
#save DF to a CSV file, saved in output_data folder
city_df.to_csv("output_data/cities.csv",index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#We sort DF by Latitude
lat_city_df = city_df.sort_values(by = "Latitud",ascending=False)
lat_city_df.head()
#We create a scatter plot with the information from lat vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Temperature"],
    marker="o",
    facecolors='blue',
    edgecolors='green',
    s=lat_city_df["Temperature"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (C°)")
plt.grid()
plt.savefig('output_data/City Latitude vs Temperature.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#We create a scatter plot with the information from Humidity vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Humidity"],
    marker="o",
    facecolors='blue',
    edgecolors='white',
    s=lat_city_df["Humidity"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig('output_data/City Latitude vs Humidity.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#We create a scatter plot with the information from Cloudiness vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Cloudiness"],
    marker="o",
    facecolors='gray',
    edgecolors='white',
    s=lat_city_df["Cloudiness"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig('output_data/City Latitude vs Cloudiness.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#We create a scatter plot with the information from Wind Speed vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Wind Speed"],
    marker="x",
    facecolors='red',
    edgecolors='black',
    s=lat_city_df["Wind Speed"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig('output_data/City Latitude vs Wind Speed.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_reg(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    return regress_values , line_eq, rvalue

# %%
# Create Northern and Southern Hemisphere DataFrames
N_lat_city_df = lat_city_df[lat_city_df['Latitud'] >= 0]
S_lat_city_df = lat_city_df[lat_city_df['Latitud'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Temperature']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,10),fontsize=15,color="red")
plt.title("North Latitude vs Temperature C°")
plt.xlabel('North Latitude')
plt.ylabel('Temperature C°')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/North Latitude vs Temperature C°.png')
plt.show()
# Out:
# The r-squared is: 0.4722563608528264

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Temperature']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,30),fontsize=15,color="red")
plt.title("South Latitude vs Temperature C°")
plt.xlabel('South Latitude')
plt.ylabel('Temperature C°')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/South Latitude vs Temperature C°.png')
plt.show()
# Out:
# The r-squared is: 0.6655209310348537

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Humidity']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(45,10),fontsize=15,color="red")
plt.title("North Latitude vs Humidity %")
plt.xlabel('North Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/North Latitude vs Humidity %.png')
plt.show()
# Out:
# The r-squared is: 0.002344425854900786

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Humidity']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-30,10),fontsize=15,color="red")
plt.title("South Latitude vs Humidity %")
plt.xlabel('South Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/South Latitude vs Humidity %.png')
plt.show()
# Out:
# The r-squared is: 0.002938084088503338

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Cloudiness']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,45),fontsize=15,color="red")
plt.title("North Latitude vs Cloudiness %")
plt.xlabel('North Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/North Latitude vs Cloudiness %.png')
plt.show()
# Out:
# The r-squared is: 0.00314634141445032

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Cloudiness']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,10),fontsize=15,color="red")
plt.title("South Latitude vs Cloudiness %")
plt.xlabel('South Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/South Latitude vs Cloudiness %.png')
plt.show()
# Out:
# The r-squared is: 0.004010330268059479

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Wind Speed']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,14),fontsize=15,color="red")
plt.title("North Latitude vs Wind Speed")
plt.xlabel('North Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/North Latitude vs Wind Speed.png')
plt.show()
# Out:
# The r-squared is: 8.064525291621298e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Wind Speed']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,9),fontsize=15,color="red")
plt.title("South Latitude vs Wind Speed")
plt.xlabel('South Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output_data/South Latitude vs Wind Speed.png')
plt.show()
# Out:
# The r-squared is: 0.002313223942012114
