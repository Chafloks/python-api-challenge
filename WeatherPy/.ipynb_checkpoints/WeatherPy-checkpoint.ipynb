# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import time

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#creates the URL to make request to weather API
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#Empty lists to store information from cities
name_cities = []
lat_cities = []
temp_cities = []
humidity_cities = []
cloud_cities = []
wind_cities = []
count = 0
#Loop to request information from each city
for i in cities:
    weather_response = requests.get(query_url + i).json()
    #We do try in case the values requested do not exist
    try:
        name_cities.append(weather_response["name"])
        lat_cities.append(weather_response["coord"]["lat"])
        temp_cities.append(weather_response["main"]["temp"])
        humidity_cities.append(weather_response["main"]["humidity"])
        cloud_cities.append(weather_response["clouds"]["all"])
        wind_cities.append(weather_response["wind"]["speed"])
        print(f'information added: [{weather_response["name"]}]')
    except KeyError:
        print("city not found")
    count += 1
    if count == 499 :
        time.sleep(60)
        count=0
    
print("----------------------------------------\nProcess completed")
# Out:
# information added: [Avera]
# information added: [Hilo]
# information added: [Novobirilyussy]
# information added: [Kosh-Agach]
# information added: [Port Alfred]
# information added: [Bluff]
# information added: [Hermanus]
# information added: [Ushuaia]
# information added: [Ōhara]
# city not found
# information added: [Albany]
# information added: [Tuatapere]
# information added: [Jamestown]
# information added: [Alindao]
# information added: [Samoded]
# information added: [Ostrovnoy]
# information added: [Morón]
# city not found
# information added: [Taoudenni]
# information added: [Saint-Joseph]
# information added: [Puerto Ayora]
# information added: [Saskylakh]
# information added: [Port Elizabeth]
# information added: [Mataura]
# information added: [Tura]
# information added: [Yellowknife]
# information added: [Bilma]
# information added: [Sarāhan]
# information added: [San Patricio]
# information added: [Rikitea]
# information added: [Bethel]
# information added: [Tuktoyaktuk]
# information added: [Tangzhai]
# information added: [Esperance]
# information added: [Solnechnyy]
# city not found
# information added: [Tūkrah]
# information added: [General Cepeda]
# information added: [Derzhavīnsk]
# information added: [Vaini]
# information added: [Tasiilaq]
# information added: [East London]
# information added: [Rio Grande]
# information added: [Vélingara]
# information added: [Igarka]
# information added: [Punta Arenas]
# information added: [Cayenne]
# information added: [Butaritari]
# information added: [Anadyr]
# information added: [Sabang]
# information added: [Severo-Kuril'sk]
# information added: [Ahipara]
# information added: [Ilulissat]
# information added: [Byron Bay]
# city not found
# information added: [Nālūt]
# information added: [Basti]
# information added: [Longyearbyen]
# information added: [Torbay]
# information added: [Andros Town]
# information added: [Havre-St-Pierre]
# information added: [Cherskiy]
# information added: [Hamilton]
# information added: [Puerto Colombia]
# information added: [Airai]
# information added: [Dixon]
# information added: [Ucluelet]
# information added: [Quelimane]
# information added: [Hithadhoo]
# information added: [Busselton]
# city not found
# information added: [Bengkulu]
# information added: [Xiantao]
# city not found
# information added: [Praia da Vitória]
# information added: [Nanortalik]
# information added: [Sherbakul']
# information added: [Ribeira Grande]
# information added: [Kruisfontein]
# information added: [Itarema]
# information added: [Khandyga]
# information added: [Kribi]
# information added: [Tual]
# information added: [Ponta do Sol]
# information added: [Lavrentiya]
# information added: [Makakilo City]
# information added: [Barrow]
# information added: [Dikson]
# information added: [Gilgit]
# information added: [Aklavik]
# information added: [Atuona]
# city not found
# information added: [Douentza]
# information added: [Kaitangata]
# information added: [Pavlodar]
# information added: [Mezen']
# information added: [Flinders]
# information added: [Berlevåg]
# information added: [Porto-Novo]
# information added: [Moa]
# information added: [Mchinji]
# information added: [Hong Kong]
# information added: [Ponta Delgada]
# information added: [Clyde River]
# information added: [Nome]
# city not found
# city not found
# information added: [Codrington]
# city not found
# information added: [New Norfolk]
# information added: [Lüderitz]
# information added: [Spassk]
# information added: [Beringovskiy]
# information added: [Salalah]
# city not found
# information added: [Bredasdorp]
# information added: [Kapaa]
# information added: [Abu Kamal]
# information added: [High Level]
# information added: [Mitsamiouli]
# information added: [Erzin]
# city not found
# information added: [Strelka]
# information added: [Jiexiu]
# information added: [Qaanaaq]
# information added: [Cidreira]
# information added: [Llangefni]
# information added: [Nikolskoye]
# information added: [Tshela]
# information added: [Port Hedland]
# information added: [Zilair]
# city not found
# information added: [Carnarvon]
# information added: [Poole]
# information added: [Kassala]
# information added: [Jurm]
# information added: [Klaksvík]
# information added: [Löbau]
# information added: [Ugoofaaru]
# city not found
# information added: [Tazovsky]
# information added: [Kahului]
# city not found
# city not found
# information added: [Mountain Home]
# information added: [Hobart]
# information added: [Mar del Plata]
# information added: [Caranavi]
# information added: [Riohacha]
# information added: [Savannah Bight]
# information added: [Sechura]
# information added: [Deniliquin]
# information added: [Leningradskiy]
# information added: [Kumul]
# information added: [Batagay-Alyta]
# information added: [Vestmannaeyjar]
# city not found
# information added: [Arraial do Cabo]
# information added: [Zhigansk]
# information added: [Dingle]
# city not found
# information added: [Imbituba]
# information added: [Cape Town]
# information added: [Srebrenik]
# information added: [Thompson]
# information added: [Bima]
# information added: [San Cristobal]
# information added: [Worthington]
# city not found
# city not found
# information added: [Karligan]
# information added: [Podor]
# information added: [Ayan]
# city not found
# information added: [Chui]
# information added: [Necochea]
# information added: [Nemuro]
# information added: [Umm Bāb]
# information added: [Nouadhibou]
# information added: [Menongue]
# information added: [Norman Wells]
# information added: [San Juan]
# information added: [Upernavik]
# information added: [Coquimbo]
# city not found
# information added: [Province of Mantua]
# information added: [Northam]
# information added: [Tomohon]
# information added: [Saint-Philippe]
# information added: [Korem]
# information added: [Amapá]
# information added: [Massakory]
# information added: [Pisco]
# information added: [Kropotkin]
# information added: [Narsaq]
# information added: [Lieksa]
# information added: [Voh]
# information added: [Bambous Virieux]
# information added: [Galesong]
# city not found
# information added: [Tambacounda]
# information added: [Camacha]
# information added: [Saint Paul Harbor]
# information added: [Acajutla]
# information added: [Preobrazheniye]
# information added: [Lagoa]
# information added: [La Ronge]
# information added: [Ranot]
# information added: [Santa Rosa]
# information added: [George Town]
# information added: [Arys]
# information added: [Christchurch]
# information added: [Vardø]
# information added: [Thinadhoo]
# city not found
# city not found
# information added: [Kuopio]
# information added: [Lompoc]
# information added: [Hannibal]
# information added: [Broome]
# information added: [Esim]
# information added: [Saint-Pierre]
# information added: [Patos]
# information added: [Port Macquarie]
# information added: [Hambantota]
# information added: [Beloha]
# information added: [Kuala Terengganu]
# information added: [Yasinya]
# information added: [Avarua]
# information added: [Calbe]
# information added: [Muzhi]
# information added: [Mayo]
# city not found
# city not found
# information added: [Kwang Binh]
# information added: [Mongoumba]
# information added: [Bulgan]
# information added: [Lorengau]
# information added: [Constitución]
# information added: [Olinda]
# information added: [Saurimo]
# information added: [Lakes Entrance]
# information added: [Funadhoo]
# information added: [Marshall]
# information added: [Merauke]
# information added: [Nivala]
# city not found
# information added: [Saint George]
# city not found
# information added: [Isangel]
# information added: [Sayyan]
# information added: [Mēga]
# information added: [Tosya]
# information added: [Pevek]
# information added: [Pinawa]
# information added: [Santa Maria]
# information added: [Taos]
# information added: [Rødbyhavn]
# information added: [Wajima]
# information added: [Labuhan]
# information added: [Sungai Penuh]
# information added: [Antofagasta]
# information added: [Barra Patuca]
# information added: [Calatrava]
# information added: [Souillac]
# information added: [Kargasok]
# information added: [Dogondoutchi]
# information added: [Viedma]
# information added: [Ixtapa]
# information added: [Tiarei]
# information added: [Rauma]
# information added: [Marsá Maţrūḩ]
# information added: [Houma]
# information added: [Balikpapan]
# information added: [Maltahöhe]
# information added: [Nacozari]
# information added: [General Pico]
# city not found
# information added: [San Rafael]
# information added: [Grand Gaube]
# information added: [Lebu]
# information added: [Casino]
# information added: [Kommunar]
# information added: [Fort Nelson]
# information added: [Vestmanna]
# information added: [Udachny]
# information added: [Mauldin]
# information added: [Nantucket]
# information added: [Umm Hājar]
# city not found
# information added: [Gwadar]
# information added: [Sept-Îles]
# information added: [Bud]
# information added: [Iqaluit]
# information added: [Honiara]
# information added: [Gävle]
# information added: [Trenggalek]
# information added: [Abu Samrah]
# information added: [Oranjemund]
# information added: [Kattivākkam]
# information added: [Chardara]
# city not found
# information added: [Jerome]
# information added: [Cabedelo]
# information added: [Richards Bay]
# information added: [Chalchihuites]
# information added: [Port Hardy]
# information added: [Hurghada]
# city not found
# information added: [Takoradze]
# information added: [Aykhal]
# information added: [Havøysund]
# information added: [Geraldton]
# information added: [Nuevo Progreso]
# information added: [Mahébourg]
# information added: [Buraidah]
# information added: [Launceston]
# information added: [Leh]
# information added: [Kavaratti]
# information added: [Alexandria]
# information added: [Linqiong]
# information added: [Sarangani]
# information added: [Grindavik]
# information added: [Muravlenko]
# information added: [Manbij]
# information added: [Cap Malheureux]
# information added: [Yashkul']
# information added: [Belozërskoye]
# information added: [Udomlya]
# information added: [Thyborøn]
# information added: [Bilibino]
# information added: [Yatou]
# information added: [Pa Sang]
# information added: [Coxen Hole]
# information added: [Ibrā’]
# information added: [Belaya Gora]
# information added: [Guatire]
# information added: [Rāzole]
# information added: [São José da Coroa Grande]
# information added: [Olafsvik]
# information added: [Mīrābād]
# information added: [North Bend]
# information added: [La Santisima Trinidad]
# information added: [Ulaangom]
# information added: [Kitimat]
# information added: [Inuvik]
# information added: [Chapais]
# information added: [Leshukonskoye]
# information added: [Dongsheng]
# information added: [Artigas]
# information added: [Laguna]
# information added: [Gmina Połaniec]
# information added: [Stepnogorsk]
# information added: [Khatanga]
# information added: [Kathmandu]
# information added: [Makassar]
# information added: [La Huacana]
# information added: [Banda Aceh]
# information added: [Carutapera]
# information added: [Englewood]
# information added: [Cockburn Town]
# information added: [Haines Junction]
# information added: [Robertsport]
# information added: [Djambala]
# information added: [Miandrivazo]
# information added: [Atambua]
# information added: [Yulara]
# information added: [Kuching]
# information added: [Lokosovo]
# information added: [Nhulunbuy]
# city not found
# information added: [Caravelas]
# information added: [Sedona]
# information added: [Muros]
# information added: [Chokurdakh]
# information added: [Kaeo]
# information added: [Cache Creek]
# information added: [Ulaanbaatar]
# city not found
# information added: [Goderich]
# information added: [Sampit]
# information added: [Khailār]
# information added: [Srednekolymsk]
# information added: [Abong Mbang]
# information added: [Exeter]
# city not found
# information added: [Quatre Cocos]
# information added: [Tabriz]
# information added: [Gamba]
# information added: [Castro]
# information added: [Erechim]
# information added: [Kiryat Gat]
# information added: [Araouane]
# information added: [Faya]
# information added: [Vila Franca do Campo]
# information added: [Taltal]
# information added: [Philadelphia]
# information added: [Pamplona]
# information added: [Faanui]
# information added: [Porto Velho]
# information added: [Koslan]
# information added: [Borzya]
# city not found
# information added: [Yangi Marg`ilon]
# information added: [Pucallpa]
# information added: [Alta Floresta]
# information added: [Porto de Moz]
# information added: [Sol'tsy]
# information added: [Seoul]
# information added: [Bobcaygeon]
# information added: [Baturaja]
# information added: [Koplik]
# information added: [Bagotville]
# information added: [Birjand]
# information added: [Panabá]
# information added: [Tigil']
# information added: [Glendive]
# information added: [Tessalit]
# information added: [Ruska Poliana]
# information added: [La Palma]
# information added: [Fortuna]
# information added: [Saldanha]
# information added: [San Isidro]
# information added: [Pachino]
# information added: [Mangan]
# information added: [Kavieng]
# information added: [Fairbanks]
# information added: [Teya]
# information added: [Kuzino]
# information added: [Port Keats]
# information added: [Paramirim]
# information added: [Ola]
# information added: [Jaguariaíva]
# information added: [High Rock]
# information added: [Fayaoué]
# information added: [Dalbandin]
# information added: [Ust'-Ilimsk]
# information added: [Murree]
# information added: [Aksu]
# information added: [Vologda]
# information added: [Swan Hill]
# information added: [Guerrero Negro]
# information added: [Hasaki]
# information added: [Bandar-e Lengeh]
# information added: [Palora]
# information added: [Ossora]
# city not found
# information added: [Saint-Augustin]
# information added: [Arrondissement de Saint-Denis]
# information added: [Khani]
# information added: [Peniche]
# information added: [Pasni]
# information added: [Turukhansk]
# information added: [Orocué]
# information added: [Córdoba]
# information added: [Tiznit Province]
# information added: [Swabi]
# information added: [Bayir]
# city not found
# information added: [Yenagoa]
# information added: [Port Lincoln]
# information added: [São Miguel do Araguaia]
# information added: [Maceió]
# information added: [Malbork]
# information added: [Wick]
# city not found
# information added: [Coyhaique]
# information added: [Barra de Tecoanapa]
# information added: [Umba]
# information added: [Piranhas]
# information added: [Cabo San Lucas]
# information added: [Arman']
# information added: [Uthal]
# information added: [The Valley]
# information added: [Wankyi]
# information added: [Vallenar]
# information added: [Calvinia]
# information added: [Agadez]
# information added: [Kendari]
# information added: [Solikamsk]
# information added: [Plácido de Castro]
# information added: [Mehamn]
# information added: [Delījān]
# information added: [Walvis Bay]
# information added: [Trairi]
# information added: [Santa Cruz de La Palma]
# information added: [Inírida]
# information added: [Akdepe]
# information added: [Talnakh]
# information added: [Cheney]
# information added: [Whitehorse]
# information added: [Lubango]
# information added: [Gizo Government Station]
# information added: [Bollnäs]
# city not found
# information added: [Zyryanka]
# information added: [Pacific Grove]
# information added: [Kokuy]
# information added: [Belyy Yar]
# information added: [Mocajuba]
# information added: [Half Moon Bay]
# information added: [San Gabriel]
# information added: [Kinsale]
# information added: [Road Town]
# information added: [Hervey Bay]
# information added: [Ulladulla]
# information added: [Texarkana]
# information added: [Bonavista]
# information added: [Bend]
# city not found
# information added: [Oktyabr'skoye]
# information added: [Viranşehir]
# information added: [Vittoria]
# information added: [Kuldīga]
# city not found
# information added: [Tamiahua]
# information added: [Uyemskiy]
# information added: [Bloomington]
# information added: [Provideniya]
# information added: [Kiruna]
# information added: [Emba]
# information added: [Sulangan]
# information added: [Namatanai]
# city not found
# information added: [Mossamedes]
# information added: [Nishihara]
# information added: [Barreiras]
# information added: [Adrar]
# information added: [Pouembout]
# information added: [Verkhoyansk]
# information added: [Rocha]
# information added: [Bariloche]
# city not found
# information added: [Saint Andrews]
# information added: [Bandarbeyla]
# information added: [Challapata]
# information added: [Koutiala]
# information added: [Alofi]
# information added: [Kungurtug]
# information added: [Sobolevo]
# information added: [Mount Gambier]
# information added: [San Buenaventura]
# information added: [Kailua]
# information added: [Port Hawkesbury]
# information added: [Turka]
# information added: [Yasnyy]
# information added: [Lienz]
# information added: [Lebrija]
# information added: [Acarí]
# information added: [São João da Barra]
# information added: [Mlonggo]
# information added: [Burnie]
# information added: [Egvekinot]
# information added: [Petropavlovsk-Kamchatskiy]
# information added: [Cuauhtémoc]
# city not found
# information added: [Katsuura]
# information added: [Hofn]
# information added: [Adré]
# information added: [Nuuk]
# information added: [Kyotera]
# information added: [Chkalovskoye]
# information added: [Port Augusta]
# information added: [Grand-Santi]
# information added: [Popondetta]
# information added: [Belmonte]
# information added: [Sisimiut]
# city not found
# information added: [Noumea]
# information added: [Mīnāb]
# information added: [Bajil]
# information added: [Hirtshals]
# information added: [Gouré]
# information added: [Pustoshka]
# information added: [Cardston]
# information added: [Azle]
# information added: [Wamba]
# information added: [Stornoway]
# information added: [Hualmay]
# information added: [Marsh Harbour]
# information added: [Sangar]
# information added: [Mikhaylovka]
# information added: [Rome]
# information added: [Varenikovskaya]
# information added: [Poltava]
# information added: [Isabela]
# information added: [Winnemucca]
# information added: [Zaysan]
# information added: [San Quintín]
# information added: [Marawi]
# information added: [Sistranda]
# information added: [San Juan del Sur]
# information added: [Daura]
# information added: [Ampanihy]
# information added: [Baykit]
# information added: [Leningori]
# information added: [Ambilobe]
# information added: [Visby]
# information added: [Uusikaupunki]
# information added: [Broken Hill]
# information added: [Surgut]
# information added: [Ushtobe]
# information added: [Moba]
# information added: [Ivanivka]
# information added: [Sørland]
# ----------------------------------------
# Process completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#We create a Data Frame from the list
city_dict = {'City': name_cities, 'Latitud': lat_cities, 'Temperature': temp_cities, 'Humidity': humidity_cities, 'Cloudiness': cloud_cities, 'Wind Speed': wind_cities}
city_df = pd.DataFrame(city_dict)
city_df.head(15)
# Out:
#               City  Latitud  Temperature  Humidity  Cloudiness  Wind Speed
# 0            Avera    33.19        33.77        49          40        2.10
# 1             Hilo    19.73        22.92        65          90        2.10
# 2   Novobirilyussy    56.95         7.64        92           0        2.20
# 3       Kosh-Agach    50.00        10.70        76          47        1.23
# 4      Port Alfred   -33.59        17.42        40           0        4.46
# 5            Bluff   -46.60         3.89        83          98        1.34
# 6         Hermanus   -34.42        14.44        81           0        1.34
# 7          Ushuaia   -54.80         4.00        87          75        3.60
# 8            Ōhara    35.25        23.71        88          75        1.50
# 9           Albany    42.60        26.62        69          83        2.82
# 10       Tuatapere   -46.13         3.89        83          71        1.34
# 11       Jamestown    42.10        25.57        65          90        3.10
# 12         Alindao     5.03        20.39        94         100        0.65
# 13         Samoded    63.61        14.61        87         100        1.88
# 14       Ostrovnoy    68.05        15.11        90          80        2.82

# %%
#save DF to a CSV file, saved in output_data folder
city_df.to_csv("output_data/cities.csv",index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#We sort DF by Latitude
lat_city_df = city_df.sort_values(by = "Latitud",ascending=False)
lat_city_df.head()
#We create a scatter plot with the information from lat vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Temperature"],
    marker="o",
    facecolors='blue',
    edgecolors='green',
    s=lat_city_df["Temperature"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (C°)")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#We create a scatter plot with the information from Humidity vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Humidity"],
    marker="o",
    facecolors='blue',
    edgecolors='white',
    s=lat_city_df["Humidity"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#We create a scatter plot with the information from Cloudiness vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Cloudiness"],
    marker="o",
    facecolors='gray',
    edgecolors='white',
    s=lat_city_df["Cloudiness"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#We create a scatter plot with the information from Wind Speed vs temp
plt.scatter(
    lat_city_df["Latitud"],
    lat_city_df["Wind Speed"],
    marker="x",
    facecolors='red',
    edgecolors='black',
    s=lat_city_df["Wind Speed"],
    alpha=1)
#add title and labels
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_reg(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    return regress_values , line_eq, rvalue

# %%
# Create Northern and Southern Hemisphere DataFrames
N_lat_city_df = lat_city_df[lat_city_df['Latitud'] >= 0]
S_lat_city_df = lat_city_df[lat_city_df['Latitud'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Temperature']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,10),fontsize=15,color="red")
plt.xlabel('North Latitude')
plt.ylabel('Temperature C°')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.4192377830044893

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Temperature']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,30),fontsize=15,color="red")
plt.xlabel('South Latitude')
plt.ylabel('Temperature C°')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5863830292296333

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Humidity']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(45,10),fontsize=15,color="red")
plt.xlabel('North Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01414321550855736

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Humidity']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-30,10),fontsize=15,color="red")
plt.xlabel('South Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006765227322131066

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Cloudiness']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,45),fontsize=15,color="red")
plt.xlabel('North Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0020249741650536415

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Cloudiness']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,10),fontsize=15,color="red")
plt.xlabel('South Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009504581121217702

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = N_lat_city_df['Latitud']
y_values = N_lat_city_df['Wind Speed']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(6,14),fontsize=15,color="red")
plt.xlabel('North Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009808818037880362

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Get X and Y values
x_values = S_lat_city_df['Latitud']
y_values = S_lat_city_df['Wind Speed']
#save return values from functions
reg, lin_eq, rvalue = lin_reg(x_values,y_values)
#Plot with Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,reg,"r-")
plt.annotate(lin_eq,(-50,9),fontsize=15,color="red")
plt.xlabel('South Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0003285909166002014
